# %% [markdown]
# **This notebook is an exercise in the [Data Visualization](https://www.kaggle.com/learn/data-visualization) course.  You can reference the tutorial at [this link](https://www.kaggle.com/alexisbcook/final-project).**
#
# ---

# %% [markdown]
# Now it's time for you to demonstrate your new skills with a project of your own!
#
# In this exercise, you will work with a dataset of your choosing.  Once you've selected a dataset, you'll design and create your own plot to tell interesting stories behind the data!
#
# ## Setup
#
# Run the next cell to import and configure the Python libraries that you need to complete the exercise.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Setup Complete

# %% [markdown]
# The questions below will give you feedback on your work. Run the following cell to set up the feedback system.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Step 1: Attach a dataset to the notebook
#
# Begin by selecting a CSV dataset from [Kaggle Datasets](https://www.kaggle.com/datasets).  If you're unsure how to do this, please revisit the instructions in the previous tutorial.
#
# Once you have selected a dataset, click on the **[+ Add data]** option in the top right corner.  This will generate a pop-up window that you can use to search for your chosen dataset.
#
# ![ex6_search_dataset](https://storage.googleapis.com/kaggle-media/learn/images/cIIWPUS.png)
#
# Once you have found the dataset, click on the **[Add]** button to attach it to the notebook.  You can check that it was successful by looking at the **Data** dropdown menu to the right of the notebook -- look for an **input** folder containing a subfolder that matches the name of the dataset.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/nMYc1Nu.png" width=30%><br/>
# </center>
#
# You can click on the carat to the left of the name of the dataset to double-check that it contains a CSV file.  For instance, the image below shows that the example dataset contains two CSV files: (1) **dc-wikia-data.csv**, and (2) **marvel-wikia-data.csv**.
#
# <center>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/B4sJkVA.png" width=30%><br/>
# </center>
#
# Once you've uploaded a dataset with a CSV file, run the code cell below **without changes** to receive credit for your work!

# %%
# Check for a dataset with a CSV file
step_1.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 2: Specify the filepath
#
# Now that the dataset is attached to the notebook, you can find its filepath.  To do this, begin by clicking on the CSV file you'd like to use.  This will open the CSV file in a tab below the notebook.  You can find the filepath towards the top of this new tab.
#
# ![ex6_filepath](https://storage.googleapis.com/kaggle-media/learn/images/fgXQV47.png)
#
# After you find the filepath corresponding to your dataset, fill it in as the value for `my_filepath` in the code cell below, and run the code cell to check that you've provided a valid filepath.  For instance, in the case of this example dataset, we would set
# ```
# my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"
# ```
# Note that **you must enclose the filepath in quotation marks**; otherwise, the code will return an error.
#
# Once you've entered the filepath, you can close the tab below the notebook by clicking on the **[X]** at the top of the tab.

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = "../input/hanzidb/hanziDB.csv"

# Check for a valid filepath to a CSV file in a dataset
step_2.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 3: Load the data
#
# Use the next code cell to load your data file into `my_data`.  Use the filepath that you specified in the previous step.

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath, index_col='frequency_rank')

# Check that a dataset has been uploaded into my_data
step_3.check()
# Out:
# Correct:

# %% [markdown]
# **_After the code cell above is marked correct_**, run the code cell below without changes to view the first five rows of the data.

# %%
# Print the first five rows of the data
my_data
# Out:
#                charcter pinyin  \
# frequency_rank
# 1                     的     de
# 2                     一     yī
# 3                     是    shì
# 4                     不     bù
# 5                     了     le
# ...                 ...    ...
# 9896                  絣   bēng
# 9897                  縀    xiá
# 9898                  縛     fù
# 9899                  縧    tāo
# 9900                  荙     dá
#
#                                                        definition radical  \
# frequency_rank
# 1                                   possessive, adjectival suffix       白
# 2                                               one; a, an; alone       一
# 3               indeed, yes, right; to be; demonstrative prono...       日
# 4                                   no, not; un-; negative prefix       一
# 5                         to finish; particle of completed action       亅
# ...                                                           ...     ...
# ...

# %% [markdown]
# ## Data Pre-processing

# %%
my_data['stroke_count'].unique()
# Out:
# array(['8', '1', '9', '4', '2', '6', '7', '5', '3', '12', '10', '11',
#        '13', '15', '14', '16', '19', '8 9', '21', '17', '18', '20', '22',
#        '23', '24', '25', '26', '30', '29', '27', '35', '28', '33', '32'],
#       dtype=object)

# %%
my_data['hsk_levl'].unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6., nan])

# %%
my_data.dtypes
# Out:
# charcter                 object
# pinyin                   object
# definition               object
# radical                  object
# radical_code            float64
# stroke_count             object
# hsk_levl                float64
# general_standard_num    float64
# dtype: object

# %%
my_data.isna().any()
# Out:
# charcter                False
# pinyin                   True
# definition               True
# radical                  True
# radical_code             True
# stroke_count            False
# hsk_levl                 True
# general_standard_num     True
# dtype: bool

# %%
my_data['pinyin'].isnull().sum()
# Out:
# 2

# %%
pinyin_mask = my_data['pinyin'].isna()
my_data[pinyin_mask]
# Out:
#                charcter pinyin                definition radical  \
# frequency_rank
# 8220                  裏    NaN  inside, interior, within       衣
# 9019                  秊    NaN                       NaN       禾
#
#                 radical_code stroke_count  hsk_levl  general_standard_num
# frequency_rank
# 8220                   145.7           13       NaN                   NaN
# 9019                   115.3            8       NaN                   NaN

# %%
my_data.loc[[8220, 9019], ['definition', 'pinyin', 'hsk_levl']] = [('lining; interior; inside; internal; also written 里', 'lǐ', 1.0), ('grain; harvest (old); variant of 年', 'hé', 1.0)]

# %%
pinyin_mask = my_data['pinyin'].isna()
my_data[pinyin_mask]
# Out:
# Empty DataFrame
# Columns: [charcter, pinyin, definition, radical, radical_code, stroke_count, hsk_levl, general_standard_num]
# Index: []

# %%
my_data.loc[[8220, 9019]]
# Out:
#                charcter pinyin  \
# frequency_rank
# 8220                  裏     lǐ
# 9019                  秊     hé
#
#                                                        definition radical  \
# frequency_rank
# 8220            lining; interior; inside; internal; also writt...       衣
# 9019                           grain; harvest (old); variant of 年       禾
#
#                 radical_code stroke_count  hsk_levl  general_standard_num
# frequency_rank
# 8220                   145.7           13       1.0                   NaN
# 9019                   115.3            8       1.0                   NaN

# %%
my_data[pinyin_mask]
# Out:
# Empty DataFrame
# Columns: [charcter, pinyin, definition, radical, radical_code, stroke_count, hsk_levl, general_standard_num]
# Index: []

# %%
filtered_data = my_data[my_data['stroke_count'].str.contains('8 9')]
filtered_data
# Out:
#                charcter pinyin                definition radical  \
# frequency_rank
# 705                   范    fàn  surname; bee-like insect       艸
#
#                 radical_code stroke_count  hsk_levl  general_standard_num
# frequency_rank
# 705                    140.5          8 9       5.0                1010.0

# %%
my_data.loc[[705],['stroke_count']] = '8'

# %%
my_data.loc[705]
# Out:
# charcter                                       范
# pinyin                                       fàn
# definition              surname; bee-like insect
# radical                                        艸
# radical_code                               140.5
# stroke_count                                   8
# hsk_levl                                     5.0
# general_standard_num                      1010.0
# Name: 705, dtype: object

# %%
my_data['stroke_count'] = my_data['stroke_count'].astype(int)

# %%
my_data['stroke_count'].unique()
# Out:
# array([ 8,  1,  9,  4,  2,  6,  7,  5,  3, 12, 10, 11, 13, 15, 14, 16, 19,
#        21, 17, 18, 20, 22, 23, 24, 25, 26, 30, 29, 27, 35, 28, 33, 32])

# %%
stroke_counts_mask = my_data['stroke_count'] > 23
my_data[stroke_counts_mask]
# Out:
#                charcter pinyin                             definition radical  \
# frequency_rank
# 3029                  矗    chù        straight, upright, erect, lofty       目
# 3843                  鑫    xīn                          used in names       金
# 4082                  囔   nāng           muttering, indistinct speech       口
# 4372                  馕   náng                   bread (persian naan)       食
# 4387                  衢     qú    highway; thoroughfare, intersection       行
# ...                 ...    ...                                    ...     ...
# 9708                  齲     qǔ                            tooth decay       齒
# 9709                  齼    chǔ                                    NaN       齒
# 9805                  鑰    yào                              key; lock       金
# 9821                  躦    cuó                                to jump       足
# 9854                  鷺     lù  heron, egret; Ardea species (various)       鳥
#
# ...

# %%
radical_mask = my_data['radical_code'].isna()
my_data[radical_mask]
# Out:
#                charcter pinyin  \
# frequency_rank
# 6088                  䜣    xīn
# 6933                  䴘     tī
# 7074                  䴙     pì
# 7188                  䥺     yé
# 7324                  䞍   qíng
# 7525                  䜩    yàn
# 7526                  䴗     jú
# 7609                  䌷   chōu
# 8006                  䦆    jué
# 8221                  䦶  zhèng
# 8222                  䲡    qiū
# 8280                  鹐   qiān
# 8749                  䦂   shàn
# 8750                  䲟    yìn
# 8751                  䴓    shī
# 8752                  䴕    liè
# 8753                  䶮    yǎn
# 8771                  䴖   jīng
# 9020                  䴔   jiāo
# 9711                  䦃   zhuō
# 9712                  䲣     yú
# 9713                  䲠   chūn
#
#                                                        definition radical  \
# frequency_rank
# 6088                                         (simplified form of      NaN
# ...

# %%
radical_mask = my_data['radical_code'].isna()
my_data = my_data[~radical_mask]
my_data[radical_mask]
# Out:
# /tmp/ipykernel_20/1556591118.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   my_data[radical_mask]
# Empty DataFrame
# Columns: [charcter, pinyin, definition, radical, radical_code, stroke_count, hsk_levl, general_standard_num]
# Index: []

# %% [markdown]
# ## Step 4: Visualize the data
#
# Use the next code cell to create a figure that tells a story behind your dataset.  You can use any chart type (_line chart, bar chart, heatmap, etc_) of your choosing!

# %%
# Create a plot
sns.scatterplot(data=my_data,x='frequency_rank',y='hsk_levl',hue='hsk_levl') # Your code here

# Check that a figure appears below
step_4.check()
# Out:
# Correct:

# %%
# Create a plot
sns.scatterplot(data=my_data,x='frequency_rank',y='stroke_count',hue='hsk_levl') # Your code here

# Check that a figure appears below
step_4.check()
# Out:
# Correct:

# %%
rank_mask = (my_data.index > 8000)
my_data[rank_mask].sort_values(by='hsk_levl')
# Out:
#                charcter pinyin  \
# frequency_rank
# 8220                  裏     lǐ
# 9019                  秊     hé
# 8001                  鶟     tú
# 8002                  鷱    gāo
# 8003                  鷲    jiù
# ...                 ...    ...
# 9896                  絣   bēng
# 9897                  縀    xiá
# 9898                  縛     fù
# 9899                  縧    tāo
# 9900                  荙     dá
#
#                                                        definition radical  \
# frequency_rank
# 8220            lining; interior; inside; internal; also writt...       衣
# 9019                           grain; harvest (old); variant of 年       禾
# 8001                                                          NaN       鳥
# 8002                                                          NaN       鳥
# 8003                                              condor, vulture       鳥
# ...                                                           ...     ...
# ...

# %%
my_data['hsk_levl'].isna().sum()
# Out:
# 7214

# %%
hsk_mask = my_data['hsk_levl'].isna()
my_data[hsk_mask]
# Out:
#                charcter pinyin                                 definition  \
# frequency_rank
# 392                   罗    luō              net for catching birds; gauze
# 642                   兰    lán                  orchid; elegant, graceful
# 654                   尼     ní              Buddhist nun; transliteration
# 751                   刘    liú                     surname; kill, destroy
# 761                   伊     yī  third person pronoun; he, she, this, that
# ...                 ...    ...                                        ...
# 9896                  絣   bēng            to baste for sewing; to connect
# 9897                  縀    xiá                                        NaN
# 9898                  縛     fù                                     to tie
# 9899                  縧    tāo                          silk cord, ribbon
# 9900                  荙     dá                             plantago major
#
#                radical  radical_code  stroke_count  hsk_levl  \
# ...

# %% [markdown]
# ## Keep going
#
# Learn how to use your skills after completing the micro-course to create data visualizations in a **[final tutorial](https://www.kaggle.com/alexisbcook/creating-your-own-notebooks)**.

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(data=my_data, x='stroke_count', y='frequency_rank')

# Add labels and title
plt.xlabel('Stroke Count')
plt.ylabel('Frequency Rank')
plt.title('Stroke Count vs. Frequency Rank')
plt.xticks(rotation = -45) # Rotates X-Axis Ticks by 45-degrees

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.histplot(data=my_data, x='stroke_count', bins=10, hue='hsk_levl')

# Add labels and title
plt.xlabel('Stroke Count')
plt.ylabel('Count')
plt.title('Stroke Count Distribution')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))  # Set the figure size
sns.boxplot(data=my_data, x='hsk_levl', y='stroke_count',fliersize=3)

# Add labels and title
plt.xlabel('HSK Level')
plt.ylabel('Stroke Count')
plt.title('Stroke Count by HSK Level')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=my_data, x='hsk_levl', y='stroke_count')

# Add labels and title
plt.xlabel('HSK Level')
plt.ylabel('Stroke Count')
plt.title('Stroke Count Distribution by HSK Level')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.jointplot(data=my_data, x='frequency_rank', y='stroke_count',hue='stroke_count')

plt.xlim(-500,10000)

# Show the plot
plt.show()

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/data-visualization/discussion) to chat with other learners.*
